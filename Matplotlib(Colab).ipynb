# %% [markdown]
# <a href="https://colab.research.google.com/github/DataCrusade1999/Python/blob/master/Matplotlib(Colab).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# BASICS

# %%
import numpy as np
import pandas as pd
import io
import matplotlib.pyplot as plt
from google.colab import files
plt.style.use('seaborn')

# %%
df=np.random.rand(10,10)
df1=np.random.rand(10,10)
plt.scatter(df,df1,edgecolors='black',alpha=0.6,c=np.random.rand(10,10),s=np.arange(100),cmap='summer')
cbar=plt.colorbar()
cbar.set_label('Colormap')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Scatter')
plt.grid(False)
plt.show()

# %%
df1=[2,3,4,5,6,7]
df2=[5,6,7,8,9,0]
df3=[6,7,7,8,9,7]
#plt.plot(df1,df2,'b--o',label='line1')
plt.plot(df1,df2,color='b',linestyle='--',marker='o',label='line1')
plt.plot(df1,df3,color='r',label='line2')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Line Graph')
plt.legend(loc='upper left')
plt.grid(False)
plt.show()

# %%
data1={'key1':np.arange(0,50),'key2':np.random.rand(50),'key3':np.random.rand(50)}
plt.scatter('key1','key2',data=data1)
plt.scatter('key1','key3',data=data1)
plt.scatter('key2','key3',data=data1)
plt.annotate('fav point',xy=(30,0.8),xytext=(40,0.9),arrowprops=dict(facecolor='green',shrink=0.05))
plt.tight_layout()
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.grid(False)
plt.show()

# %%
image=plt.imshow(np.random.rand(400,400))

# %% [markdown]
# AVAILABLE STYLES

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# BAR CHART

# %%
plt.bar(np.arange(25)+0.25,np.arange(25),width=0.25,color='b',label='bars')
plt.bar(np.arange(25)-0.25,np.arange(25),width=0.25,color='y',label='New Bars')
plt.plot(np.arange(25),np.arange(25),color='k',label='line')
plt.annotate('point',xy=(8,7.5),xytext=(12,14.5),arrowprops={'facecolor':'orange','shrink':0.05})
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Bar Chart')
plt.grid(False)
plt.legend()
plt.show()

# %% [markdown]
# WORKING ON A CSV FILE

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-a2970c16-1594-4fee-96f6-4c26b1dca02e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a2970c16-1594-4fee-96f6-4c26b1dca02e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving houses_to_rent.csv to houses_to_rent.csv

# %%
df1=pd.read_csv(io.BytesIO(uploaded['houses_to_rent.csv']))

# %% [markdown]
# PERFORMING EDA

# %%
#Getting Some Important Metrics
print(df1.describe())
# Out:
#        Unnamed: 0         city  ...     bathroom  parking spaces
# count  6080.00000  6080.000000  ...  6080.000000     6080.000000
# mean   3039.50000     0.863322  ...     2.341612        1.756250
# std    1755.28915     0.343535  ...     1.438860        1.611909
# min       0.00000     0.000000  ...     1.000000        0.000000
# 25%    1519.75000     1.000000  ...     1.000000        1.000000
# 50%    3039.50000     1.000000  ...     2.000000        1.000000
# 75%    4559.25000     1.000000  ...     3.000000        2.000000
# max    6079.00000     1.000000  ...    10.000000       12.000000
#
# [8 rows x 6 columns]

# %%
print(df1.shape)
# Out:
# (6080, 14)

# %%
print(df1.columns)
# Out:
# Index(['Unnamed: 0', 'city', 'area', 'rooms', 'bathroom', 'parking spaces',
#        'floor', 'animal', 'furniture', 'hoa', 'rent amount', 'property tax',
#        'fire insurance', 'total'],
#       dtype='object')

# %%
df2=df1.head(8)['fire insurance'].str.extract('(\d+)').astype(int)
print(df2)
# Out:
#      0
# 0  121
# 1   11
# 2   89
# 3   16
# 4   16
# 5   28
# 6   64
# 7   17

# %% [markdown]
# PLOTTING THE DATA FROM CSV FILE

# %%
# After performing EDA We Found Correlation Between City And Property Tax
plt.scatter(df1.head(8)['property tax'],df1.head(8)['city'],c=df2,s=df2,marker='o',alpha=0.6,cmap='summer',edgecolors='black')
cbar=plt.colorbar()
cbar.set_label('Fire Insurance')
plt.xlabel('Property Tax')
plt.ylabel('City Or Not')
plt.title('Houses To Rent')
plt.tight_layout()
plt.grid(False)
plt.show()

# %%
# From EDA We Can See The Correlation Between Rent Amount And Rooms
plt.barh(df1.head(10)['rent amount'],df1.head(10)['rooms'],)
plt.xlabel('Number Of Rooms')
plt.ylabel('Rent Amount')
plt.title('Houses To Rent')
plt.grid(False)
plt.show()

# %% [markdown]
# PIE CHART

# %%
df2=list(df1.head(5)['rooms'])
print(df2)
# Out:
# [3, 2, 5, 2, 1]

# %%
plt.pie(df2,explode=[0,0,0,0,0.1],labels=['3 Rooms','2 Rooms','5 Rooms','2 Rooms','1 Room'],shadow=True,startangle=90,wedgeprops={'edgecolor':'black'},autopct='%1.1f%%')
plt.show()
